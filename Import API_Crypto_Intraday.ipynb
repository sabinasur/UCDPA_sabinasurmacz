# %%
import requests

# %%
url = 'https://www.alphavantage.co/query?function=CRYPTO_INTRADAY&symbol=ETH&market=USD&interval=5min&apikey=9CSNSWOXK3TNQDR7 '

# %%
request = requests.get(url)

# %%
print(request.status_code)
# Out:
# 200

# %%
print(request.text)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Crypto Intraday (5min) Time Series",
#         "2. Digital Currency Code": "ETH",
#         "3. Digital Currency Name": "Ethereum",
#         "4. Market Code": "USD",
#         "5. Market Name": "United States Dollar",
#         "6. Last Refreshed": "2022-09-17 22:35:00",
#         "7. Interval": "5min",
#         "8. Output Size": "Compact",
#         "9. Time Zone": "UTC"
#     },
#     "Time Series Crypto (5min)": {
#         "2022-09-17 22:35:00": {
#             "1. open": "1461.83000",
#             "2. high": "1463.22000",
#             "3. low": "1461.59000",
#             "4. close": "1462.86000",
#             "5. volume": 1593
#         },
#         "2022-09-17 22:30:00": {
#             "1. open": "1457.89000",
#             "2. high": "1462.12000",
#             "3. low": "1457.88000",
#             "4. close": "1461.82000",
#             "5. volume": 1497
#         },
#         "2022-09-17 22:25:00": {
# ...

# %%
data=request.json()

# %%
print(data)
# Out:
# {'Meta Data': {'1. Information': 'Crypto Intraday (5min) Time Series', '2. Digital Currency Code': 'ETH', '3. Digital Currency Name': 'Ethereum', '4. Market Code': 'USD', '5. Market Name': 'United States Dollar', '6. Last Refreshed': '2022-09-17 22:35:00', '7. Interval': '5min', '8. Output Size': 'Compact', '9. Time Zone': 'UTC'}, 'Time Series Crypto (5min)': {'2022-09-17 22:35:00': {'1. open': '1461.83000', '2. high': '1463.22000', '3. low': '1461.59000', '4. close': '1462.86000', '5. volume': 1593}, '2022-09-17 22:30:00': {'1. open': '1457.89000', '2. high': '1462.12000', '3. low': '1457.88000', '4. close': '1461.82000', '5. volume': 1497}, '2022-09-17 22:25:00': {'1. open': '1458.34000', '2. high': '1460.57000', '3. low': '1455.66000', '4. close': '1457.88000', '5. volume': 1615}, '2022-09-17 22:20:00': {'1. open': '1460.12000', '2. high': '1460.13000', '3. low': '1458.19000', '4. close': '1458.34000', '5. volume': 955}, '2022-09-17 22:15:00': {'1. open': '1461.87000', '2. high': 
# ...

# %%
print(data['Meta Data'])
# Out:
# {'1. Information': 'Crypto Intraday (5min) Time Series', '2. Digital Currency Code': 'ETH', '3. Digital Currency Name': 'Ethereum', '4. Market Code': 'USD', '5. Market Name': 'United States Dollar', '6. Last Refreshed': '2022-09-17 22:35:00', '7. Interval': '5min', '8. Output Size': 'Compact', '9. Time Zone': 'UTC'}
